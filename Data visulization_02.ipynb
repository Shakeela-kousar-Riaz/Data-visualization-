# %% [markdown]
# **Data visulization using usa housing dataset**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import sklearn
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.rcParams["figure.figsize"] = [10,5]
# Ignore warnings

import warnings
# Set the warning filter to ignore FutureWarning
warnings.simplefilter(action = "ignore", category = FutureWarning)

# %%
full_data = pd.read_csv('/content/USA_Housing.csv')

# %%
full_data.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
print('train data:',full_data.shape)
# Out:
# train data: (5000, 7)

# %%
full_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 273.6+ KB

# %%
full_data.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
full_data.shape
# Out:
# (5000, 7)

# %%
sns.lineplot(x = "Avg. Area Income", y="Avg. Area House Age", data=full_data)
plt.show()

# %%
sns.stripplot(x = "Avg. Area Income", y = "Avg. Area House Age", data=full_data)
plt.show()

# %%
sns.swarmplot(x="Avg. Area Income", y="Avg. Area House Age", data= full_data)
plt.show()

# %%
sns.displot(full_data['Avg. Area Income'])
plt.show()

# %%
sns.displot(full_data['Area Population'])
plt.show()

# %%
sns.lineplot(x="Avg. Area Income",y="Area Population", hue="Price",data=full_data)
plt.show()

# %%
sns.barplot(x="Avg. Area Income", y="Area Population", hue="Avg. Area Income",data=full_data)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-934ca4566f5b> in <cell line: 1>()
# ----> 1 sns.barplot(x="Avg. Area Income", y="Area Population", hue="Price",data=full_data)
#       2 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2753         estimator = "size"
#    2754
# -> 2755     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                           estimator, errorbar, n_boot, units, seed,
#    2757                           orient, color, palette, saturation,
#
# ...

# %%
sns.violinplot(x="Avg. Area House Age", y="Area Population", hue="Avg. Area Income", data=full_data)
plt.sh
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-3ae23ad0db21> in <cell line: 1>()
# ----> 1 sns.violinplot(x="Avg. Area House Age", y="Area Population", hue="Price", data=full_data)
#       2 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py in violinplot(data, x, y, hue, order, hue_order, bw, cut, scale, scale_hue, gridsize, width, inner, split, dodge, orient, linewidth, color, palette, saturation, ax, **kwargs)
#    2303 ):
#    2304
# -> 2305     plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,
#    2306                              bw, cut, scale, scale_hue, gridsize,
#    2307                              width, inner, split, dodge, orient, linewidth,
#
# ...

# %%
sns.pointplot(x="Avg. Area House Age",y="Area Population",hue="Avg. Area Income", data=full_data)
plt.show()
