# %% [markdown]
# # Operator

# %% [markdown]
# **ARITHMETIC OPERATOR**
#
# **Addition (+)**
#
# **Subtraction (-)**
#
#
# **Multipication (*)**
#
# **Division (/)**
#
# **Modulus (%)**

# %%
x = 23
y = 45

# %%
print(x+y) #Add two values
# Out:
# 68

# %%
print(x-y) #Subtract two values
# Out:
# -22

# %%
#assign the values of variables
a = 4
b = 5
print(a*b)  #Multiple two valu
# Out:
# 20

# %%
print(a**b)   # exponent the values
# Out:
# 1024

# %%
print(a/b)   #division two values
# Out:
# 0.8

# %%
print(16%5)   #find modulus between values
# Out:
# 1

# %%
a = 45/5
a
# Out:
# 9.0

# %%
var1 = 20
var2 = 40
sum = var1+var2 #Adding two values
print(sum)
# Out:
# 60

# %%
#simplify the program to find the area of rectangle
#Length of the rectangle
length = 5
#Height  of the reactanle
height = 6
#find the area of the rectangle
area = length * height #Find the area
print(area)
# Out:
# 30

# %%
#Assign the vale of variable x
x = 445
#Assign the value of variablke y
y = 654
result = x==y
#Printing the result of the comparision
print("Is a x equal to y?",result)
# Out:
# Is a x equal to y? False

# %%
#Cheaking if x is not equal to y using inequality(!=)
result = x != y

#printing the result of comparision
print("Is x is not equal to b?",result)
# Out:
# Is x is not equal to b? True

# %%
#Checking if x is greather than y using the greather than operator(>)
result = x>y
print("Is x is greather than y?",result)
# Out:
# Is x is greather than y? False

# %%
#Checking if x is lee than y using less than operator(<)
result = x<y
print("Is x less than y?" ,result)
# Out:
# Is x less than y? True

# %%
#Checking x is geather than equal y using greather than operator(>=)
x >= y
# Out:
# False

# %%
#Checking x less than equal y using less than operator(<=)
x <= y
# Out:
# True

# %%
x == y
# Out:
# False

# %% [markdown]
# # IF

# %%
#Assign the value of variable x
x = 800
#Assign the value of variable y
y = 400
if x>y:
  print("a greather than b")
# Out:
# a greather than b

# %%
a = 330
b = 550
if a<b:
  print("a smaller than b")
# Out:
# a smaller than b

# %% [markdown]
# # Elif

# %%
x = 55
y = 55
if x>y:
  print("x greather than y")
elif x==y:
  print("x equal to y")
# Out:
# x equal to y

# %%
a = 666
b = 555
if a>b:
  print("a greather than b")
elif a==b:
  print("a equal to b")
else:
  print("b greather than a")
# Out:
# a greather than b

# %% [markdown]
# # AND

# %%
a = 333
b = 444
c = 555
if a>b and a<c:  #Using And logic operation
  print("both condition are True")

# %%
a>b and a<c
# Out:
# False

# %% [markdown]
# # OR

# %%
a = 342
b = 234
c = 654
if a>b or a>c:  #using OR logic operator
  print("At least one condition is True")
# Out:
# At least one condition is True

# %%
a>b or a<c
# Out:
# True

# %%
#using OR logic operation
if a>b or b>c:
 print("At least one condition is true ")
# Out:
# At least one condition is true

# %%
a>b or b>c
# Out:
# True

# %% [markdown]
# # NOT

# %%
x = 25
y = 45
if not x>y:
  print("a is not greather than b")
# Out:
# a is not greather than b

# %%
not x>y
# Out:
# True

# %% [markdown]
# ## Membership operator
#  **in**
#
# **not in**

# %% [markdown]
# ## in returns True if a sequence with the specified value is present in the object.

# %%
'apple' in ['banana','apple','orange']
# Out:
# True

# %%
'apple' in  ['orange','banana','mango']
# Out:
# False

# %%
'apple' not in ['orange','mango','banana']
# Out:
# True

# %%
'red' in ['green','Red','yellow']
# Out:
# False

# %%
'red' not in ['green','brown','yellow','orange']
# Out:
# True

# %% [markdown]
# ** THANK YOU FOR WATCHING VIDEO**
